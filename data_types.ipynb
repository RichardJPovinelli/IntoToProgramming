# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RichardJPovinelli/IntoToProgramming/blob/main/data_types.ipynb)

# %%
# 1. Integer datatype

# %%
type(5)
# Out:
# int

# %% [markdown]
# ## 2. Float datatype

# %%
type(3.14)
# Out:
# float

# %% [markdown]
# ## 3. String datatype

# %%
type("Hello, World!")
# Out:
# str

# %% [markdown]
# ## 4. Boolean datatype

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## 5. Test out typing other values
#
# **TODO:**
# - type(-2000)
# - type(2.27)
# - type("Goodnight Moon")
# - type(False)
