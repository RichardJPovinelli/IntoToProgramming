# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RichardJPovinelli/IntoToProgramming/blob/main/errors.ipynb)

# %%
# Errors
Run the following code cell. Identify and fix any errors.

# %%
print("Hello out there.")
print("I will add two numbers for you.")
1n = input("Enter a whole number: ")
n2 = input("Enter another whole number: ")
sum = n1 + n2


print("The sum of those two numbers is")
print(sum)
